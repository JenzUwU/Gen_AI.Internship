# %% [markdown]
# <a href="https://colab.research.google.com/github/JenzUwU/Gen_AI.Internship/blob/main/ActivationFunctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sigmoid Activation Function
# Formula : sigmoid(x) = 1 / 1 + e^-x

import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

input_x = np.array([-15, -5, -2, 0, 2, 5, 15])
output_of_x = sigmoid(input_x)

print("Sigmoid Input:", input_x)
print("Sigmoid Output:", output_of_x)
# Out:
# Sigmoid Input: [-15  -5  -2   0   2   5  15]
# Sigmoid Output: [3.05902227e-07 6.69285092e-03 1.19202922e-01 5.00000000e-01
#  8.80797078e-01 9.93307149e-01 9.99999694e-01]

# %%
# Softmax Activation Function
# Formula: softmax(x_i) = exp(x_i) / sum(exp(x_j)) for all j

def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

input_x = np.array([0.5, 1.5, 2.5, 3.5])
output_of_x = softmax(input_x)

print("Softmax Input:", input_x)
print("Softmax Output:", output_of_x)
# Out:
# Softmax Input: [0.5 1.5 2.5 3.5]
# Softmax Output: [0.0320586  0.08714432 0.23688282 0.64391426]

# %%
# ReLU Activation Function
# Formula: ReLU(x) = max(0, x)

def relu(x):
    return np.maximum(0, x)

input_x = np.array([-8, -4, -2, 0, 2, 4, 8])
output_of_x = relu(input_x)

print("ReLU Input:", input_x)
print("ReLU Output:", output_of_x)
# Out:
# ReLU Input: [-8 -4 -2  0  2  4  8]
# ReLU Output: [0 0 0 0 2 4 8]

# %%
# Leaky ReLU Activation Function
# Formula: LeakyReLU(x) = x if x > 0 else alpha * x

def leaky_relu(x, alpha=0.1):
    return np.where(x > 0, x, alpha * x)

input_x = np.array([-3, -2, -1, 0, 1, 2, 3])
output_of_x = leaky_relu(input_x)

print("Leaky ReLU Input:", input_x)
print("Leaky ReLU Output:", output_of_x)
# Out:
# Leaky ReLU Input: [-3 -2 -1  0  1  2  3]
# Leaky ReLU Output: [-0.3 -0.2 -0.1  0.   1.   2.   3. ]

# %%
# Tanh Activation Function
# Formula: tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

def tanh(x):
    return np.tanh(x)

input_x = np.array([-6, -3, -1, 0, 1, 3, 6])
output_of_x = tanh(input_x)

print("Tanh Input:", input_x)
print("Tanh Output:", output_of_x)
# Out:
# Tanh Input: [-6 -3 -1  0  1  3  6]
# Tanh Output: [-0.99998771 -0.99505475 -0.76159416  0.          0.76159416  0.99505475
#   0.99998771]
